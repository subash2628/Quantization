# %%
pwd
# Out:
# '/home/subash/Quantization'

# %%
ls
# Out:
# 2.ipynb                      ml-1m/                 ratings.dat
# 3.ipynb                      ml-1m.zip              unsloth_compiled_cache/
# contrastive_rec_train.jsonl  movielens_train.jsonl  users.dat
# llama3.2-lora-final/         movies.dat             wandb/
# main.ipynb                   outputs/

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121 && \
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git" && \
# !pip install --no-deps xformers trl peft accelerate bitsandbytes && \
# !pip install datasets transformers
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 49.6 MB/s  0:00:00
# ...
# zsh:1: command not found: !pip

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
print(f"Number of GPUs: {torch.cuda.device_count()}")

# Should show RTX 3090 after setting CUDA_VISIBLE_DEVICES=1
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
print(f"Selected GPU: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.5.1+cu121
# CUDA available: True
# CUDA version: 12.1
# Number of GPUs: 2
# Selected GPU: NVIDIA GeForce RTX 4070

# %%
import torch

print("All available GPUs:")
for i in range(torch.cuda.device_count()):
    print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
# Out:
# All available GPUs:
# GPU 0: NVIDIA GeForce RTX 4070

# %%
import torch

print("All available GPUs:")
for i in range(torch.cuda.device_count()):
    print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
    print(f"  Memory: {torch.cuda.get_device_properties(i).total_memory / 1024**3:.2f} GB")
# Out:
# All available GPUs:
# GPU 0: NVIDIA GeForce RTX 4070
#   Memory: 11.60 GB

# %%
python3 -c "import torch; print(f'GPUs: {torch.cuda.device_count()}'); [print(f'GPU {i}: {torch.cuda.get_device_name(i)}') for i in range(torch.cuda.device_count())]"
# Out:
#   Cell In[9], line 1
#     python3 -c "import torch; print(f'GPUs: {torch.cuda.device_count()}'); [print(f'GPU {i}: {torch.cuda.get_device_name(i)}') for i in range(torch.cuda.device_count())]"
#                ^
# SyntaxError: invalid syntax

# %%
import torch; print(f'GPUs: {torch.cuda.device_count()}'); [print(f'GPU {i}: {torch.cuda.get_device_name(i)}') for i in range(torch.cuda.device_count())]
# Out:
# GPUs: 1
# GPU 0: NVIDIA GeForce RTX 4070
# [None]

# %%
# !nvidia-smi
# Out:
# Sun Jan 25 00:31:09 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.95.05              Driver Version: 580.95.05      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3090        Off |   00000000:01:00.0 Off |                  N/A |
# |  0%   22C    P8              7W /  350W |   10293MiB /  24576MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# FIRST CELL - Must be run FIRST before any imports
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Use GPU 0 (RTX 3090), not 1!

# SECOND CELL - Verify it's working
import torch
print(f"Number of visible GPUs: {torch.cuda.device_count()}")
print(f"Using GPU: {torch.cuda.get_device_name(0)}")
print(f"Available memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
# Out:
# Number of visible GPUs: 1
# Using GPU: NVIDIA GeForce RTX 4070
# Available memory: 11.60 GB

# %%
import os
print("Current CUDA_VISIBLE_DEVICES:", os.environ.get('CUDA_VISIBLE_DEVICES', 'Not set'))
# Out:
# Current CUDA_VISIBLE_DEVICES: 0

# %%
import os
import sys

# Remove torch from memory if already loaded
if 'torch' in sys.modules:
    del sys.modules['torch']

# Force set the environment variable
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# Verify it's set
print("CUDA_VISIBLE_DEVICES is now:", os.environ.get('CUDA_VISIBLE_DEVICES'))

# Now import torch
import torch
print(f"\nNumber of visible GPUs: {torch.cuda.device_count()}")
print(f"Using GPU: {torch.cuda.get_device_name(0)}")
print(f"Available memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
# Out:
# CUDA_VISIBLE_DEVICES is now: 0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 15
#      12 print("CUDA_VISIBLE_DEVICES is now:", os.environ.get('CUDA_VISIBLE_DEVICES'))
#      14 # Now import torch
# ---> 15 import torch
#      16 print(f"\nNumber of visible GPUs: {torch.cuda.device_count()}")
#      17 print(f"Using GPU: {torch.cuda.get_device_name(0)}")
#
# File ~/miniconda3/envs/unsloth_env/lib/python3.10/site-packages/torch/__init__.py:2504
#    2501 if not _running_with_deploy():
#    2502     from torch import compiler as compiler
# -> 2504     class _TritonLibrary:
#    2505         lib = torch.library.Library("triton", "DEF")
#    2506         ops_table: _Dict[_Tuple[str, str], _Callable] = {}
#
# File ~/miniconda3/envs/unsloth_env/lib/python3.10/site-packages/torch/__init__.py:2505, in _TritonLibrary()
#    2504 class _TritonLibrary:
# ...

# %%
import torch

# Set up device
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# Move model to device
model = model.to(device)

# Create or load your data FIRST, then move it
data = torch.randn(100, 10)  # Example: create some data
data = data.to(device)  # Now this will work

print(f"Using device: {torch.cuda.get_device_name(1)}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import torch
#       3 # Set up device
#       4 device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
#
# File ~/miniconda3/envs/unsloth_env/lib/python3.10/site-packages/torch/__init__.py:2504
#    2501 if not _running_with_deploy():
#    2502     from torch import compiler as compiler
# -> 2504     class _TritonLibrary:
#    2505         lib = torch.library.Library("triton", "DEF")
#    2506         ops_table: _Dict[_Tuple[str, str], _Callable] = {}
#
# File ~/miniconda3/envs/unsloth_env/lib/python3.10/site-packages/torch/__init__.py:2505, in _TritonLibrary()
#    2504 class _TritonLibrary:
# -> 2505     lib = torch.library.Library("triton", "DEF")
#    2506     ops_table: _Dict[_Tuple[str, str], _Callable] = {}
#    2508     @classmethod
# ...

# %%
import torch

# Set up device
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# Move model to device
model = model.to(device)

# Create or load your data FIRST, then move it
data = torch.randn(100, 10)  # Example: create some data
data = data.to(device)  # Now this will work

print(f"Using device: {torch.cuda.get_device_name(1)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
#       6 # Move model to device
# ----> 7 model = model.to(device)
#       9 # Create or load your data FIRST, then move it
#      10 data = torch.randn(100, 10)  # Example: create some data
#
# NameError: name 'model' is not defined

# %%
import torch
import torch.nn as nn

# Set up device
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# CREATE the model first (example: a simple neural network)
model = nn.Sequential(
    nn.Linear(10, 50),
    nn.ReLU(),
    nn.Linear(50, 1)
)

# NOW move model to device
model = model.to(device)

# Create data and move it to device
data = torch.randn(100, 10)
data = data.to(device)

print(f"Using device: {torch.cuda.get_device_name(1) if torch.cuda.is_available() else 'CPU'}")
# Out:
# Using device: NVIDIA GeForce RTX 3090

# %%
import torch
from unsloth import FastLanguageModel, is_bfloat16_supported
from datasets import load_dataset
from trl import SFTTrainer
from transformers import TrainingArguments

# Set device to cuda:1 (RTX 3090)
device = torch.device("cuda:1")
torch.cuda.set_device(1)

# Verify GPU
print(f"Using GPU: {torch.cuda.get_device_name(1)}")
print(f"Available memory: {torch.cuda.get_device_properties(1).total_memory / 1024**3:.2f} GB")

max_seq_length = 2048

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/llama-3-8b-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = None,
    load_in_4bit = True,
    device_map = {"": 1}  # Force to use GPU 1 (RTX 3090)
)

model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj"],
    lora_alpha = 16,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
)

# Load and format dataset
dataset = load_dataset('json', data_files='contrastive_rec_train.jsonl', split='train')

def formatting_func(examples):
    texts = []
    EOS_TOKEN = tokenizer.eos_token
    for instruction, input_text, output in zip(examples['instruction'], examples['input'], examples['output']):
        text = f"""### Instruction:
{instruction}

### Input:
{input_text}

### Response:
{output}{EOS_TOKEN}"""
        texts.append(text)
    return {"text": texts}

dataset = dataset.map(formatting_func, batched=True, remove_columns=dataset.column_names)

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    packing = False,
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        num_train_epochs = 1,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none",
    ),
)

trainer_stats = trainer.train()

print("\n=== Training Complete ===")
print(f"Training completed on: {torch.cuda.get_device_name(1)}")
# Out:
# Using GPU: NVIDIA GeForce RTX 3090
# Available memory: 23.54 GB
# ==((====))==  Unsloth 2026.1.4: Fast Llama patching. Transformers: 4.57.6.
#    \\   /|    NVIDIA GeForce RTX 4070. Num GPUs = 2. Max memory: 11.595 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 8.9. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post1. FA2 = True]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# ...
# Unsloth: Tokenizing ["text"] (num_proc=32):   0%|          | 0/6040 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 82
#      55 dataset = dataset.map(formatting_func, batched=True, remove_columns=dataset.column_names)
#      57 trainer = SFTTrainer(
#      58     model = model,
# ...

# %%
import torch
from unsloth import FastLanguageModel, is_bfloat16_supported
from datasets import load_dataset
from trl import SFTTrainer
from transformers import TrainingArguments

# Set device to cuda:1 (RTX 3090) BEFORE loading the model
torch.cuda.set_device(1)

# Verify GPU
print(f"Using GPU: {torch.cuda.get_device_name(1)}")
print(f"Available memory: {torch.cuda.get_device_properties(1).total_memory / 1024**3:.2f} GB")
print(f"Current CUDA device: {torch.cuda.current_device()}")

max_seq_length = 2048

# Load model - device_map will automatically use current device
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/llama-3-8b-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = None,
    load_in_4bit = True,
    device_map = {"": torch.cuda.current_device()}  # Use current device (cuda:1)
)

model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj"],
    lora_alpha = 16,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
)

# Load and format dataset - replace with your actual file path
dataset = load_dataset('json', data_files='contrastive_rec_train.jsonl', split='train')

def formatting_func(examples):
    texts = []
    EOS_TOKEN = tokenizer.eos_token
    for instruction, input_text, output in zip(examples['instruction'], examples['input'], examples['output']):
        text = f"""### Instruction:
{instruction}

### Input:
{input_text}

### Response:
{output}{EOS_TOKEN}"""
        texts.append(text)
    return {"text": texts}

dataset = dataset.map(formatting_func, batched=True, remove_columns=dataset.column_names)

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    packing = False,
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        num_train_epochs = 1,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none",
    ),
)

trainer_stats = trainer.train()

print("\n=== Training Complete ===")
print(f"Training completed on: {torch.cuda.get_device_name(1)}")
# Out:
# Using GPU: NVIDIA GeForce RTX 3090
# Available memory: 23.54 GB
# Current CUDA device: 1
# ==((====))==  Unsloth 2026.1.4: Fast Llama patching. Transformers: 4.57.6.
#    \\   /|    NVIDIA GeForce RTX 4070. Num GPUs = 2. Max memory: 11.595 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 8.9. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post1. FA2 = True]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 83
#      56 dataset = dataset.map(formatting_func, batched=True, remove_columns=dataset.column_names)
#      58 trainer = SFTTrainer(
#      59     model = model,
#      60     tokenizer = tokenizer,
#    (...)
#      80     ),
#      81 )
# ...

# %%
import torch
import gc

# Clear any existing GPU cache
torch.cuda.empty_cache()
gc.collect()

# Set device to cuda:1 (RTX 3090)
torch.cuda.set_device(1)

# Check available memory
print(f"Using GPU: {torch.cuda.get_device_name(1)}")
print(f"Total memory: {torch.cuda.get_device_properties(1).total_memory / 1024**3:.2f} GB")
print(f"Allocated memory: {torch.cuda.memory_allocated(1) / 1024**3:.2f} GB")
print(f"Cached memory: {torch.cuda.memory_reserved(1) / 1024**3:.2f} GB")
print(f"Free memory: {(torch.cuda.get_device_properties(1).total_memory - torch.cuda.memory_allocated(1)) / 1024**3:.2f} GB")
# Out:
# Using GPU: NVIDIA GeForce RTX 3090
# Total memory: 23.54 GB
# Allocated memory: 6.45 GB
# Cached memory: 16.10 GB
# Free memory: 17.09 GB

# %%
# Clear cached memory
torch.cuda.empty_cache()
gc.collect()
# Out:
# 381

# %%
import json

# Read first line to see the structure
with open('contrastive_rec_train.jsonl', 'r') as f:
    first_line = json.loads(f.readline())
    print(json.dumps(first_line, indent=2))
# Out:
# {
#   "instruction": "Analyze the user's history to identify their preference. Compare two potential movies and explain which one is the better recommendation.",
#   "input": "History: Bug's Life, A (1998), Antz (1998), Hunchback of Notre Dame, The (1996), Hercules (1997), Mulan (1998). Option A: Pocahontas (1995) (Animation|Children's|Musical|Romance). Option B: Turbo: A Power Rangers Movie (1997) (Action|Adventure|Children's).",
#   "output": "The better recommendation is Option A. Reasoning: The user has shown a strong preference for themes found in Animation|Children's|Musical|Romance. Option B (Action|Adventure|Children's) does not align with their recent viewing patterns."
# }

# %%
import torch
import gc
import json
from unsloth import FastLanguageModel, is_bfloat16_supported
from datasets import load_dataset
from trl import SFTTrainer
from transformers import TrainingArguments
import os

# CRITICAL: Set this BEFORE any CUDA operations
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# Now set device - after setting CUDA_VISIBLE_DEVICES, GPU 1 becomes GPU 0
torch.cuda.set_device(0)

print(f"Using GPU: {torch.cuda.get_device_name(0)}")
print(f"Available memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")

max_seq_length = 2048

# Load model
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/llama-3-8b-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = None,
    load_in_4bit = True,
)

print(f"Model loaded. Memory allocated: {torch.cuda.memory_allocated(0) / 1024**3:.2f} GB")

model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj"],
    lora_alpha = 16,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
)

# Load your dataset
dataset = load_dataset('json', data_files='contrastive_rec_train.jsonl', split='train')

print(f"Dataset loaded. Number of examples: {len(dataset)}")
print(f"Dataset columns: {dataset.column_names}")

# Format dataset
def formatting_func(examples):
    texts = []
    EOS_TOKEN = tokenizer.eos_token
    for instruction, input_text, output in zip(examples['instruction'], examples['input'], examples['output']):
        text = f"""### Instruction:
{instruction}

### Input:
{input_text}

### Response:
{output}{EOS_TOKEN}"""
        texts.append(text)
    return {"text": texts}

dataset = dataset.map(formatting_func, batched=True, remove_columns=dataset.column_names)

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    packing = False,
    args = TrainingArguments(
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 8,
        warmup_steps = 5,
        num_train_epochs = 1,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none",
    ),
)

print("\n" + "="*50)
print("Starting training on RTX 3090...")
print("="*50 + "\n")

trainer_stats = trainer.train()

print("\n" + "="*50)
print("Training Complete!")
print("="*50)
print(f"Training completed on: {torch.cuda.get_device_name(0)}")
print(f"Training loss: {trainer_stats.training_loss:.4f}")
print(f"Final memory allocated: {torch.cuda.memory_allocated(0) / 1024**3:.2f} GB")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Using GPU: NVIDIA GeForce RTX 4070
# Available memory: 11.60 GB
# ==((====))==  Unsloth 2026.1.4: Fast Llama patching. Transformers: 4.57.6.
#    \\   /|    NVIDIA GeForce RTX 4070. Num GPUs = 2. Max memory: 11.595 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 8.9. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post1. FA2 = True]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Model loaded. Memory allocated: 5.33 GB
# Unsloth 2026.1.4 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.
# Dataset loaded. Number of examples: 6040
# Dataset columns: ['instruction', 'input', 'output']
# ...
